# %%
# !pip install torch torchvision torchaudio
# !pip install easyocr
# Out:
# Collecting torch
#   Downloading torch-1.13.1-cp310-cp310-win_amd64.whl (162.6 MB)
#      -------------------------------------- 162.6/162.6 MB 1.0 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.14.1-cp310-cp310-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 825.4 kB/s eta 0:00:00
# Collecting torchaudio
#   Downloading torchaudio-0.13.1-cp310-cp310-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.4.0)
# Requirement already satisfied: numpy in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (1.23.3)
# Requirement already satisfied: requests in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision) (3.4)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.13.1 torchaudio-0.13.1 torchvision-0.14.1
# Collecting easyocr
#   Downloading easyocr-1.6.2-py3-none-any.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 144.7 kB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.5 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (0.14.1)
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post4-cp310-cp310-win_amd64.whl (94 kB)
#      -------------------------------------- 94.5/94.5 kB 207.5 kB/s eta 0:00:00
# Requirement already satisfied: Pillow in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (9.2.0)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
#      ------------------------------------ 151.7/151.7 kB 133.0 kB/s eta 0:00:00
# Requirement already satisfied: torch in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: numpy in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.23.3)
# Requirement already satisfied: scipy in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.9.3)
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-win_amd64.whl (313 kB)
#      ------------------------------------ 313.0/313.0 kB 220.2 kB/s eta 0:00:00
# Collecting Shapely
#   Downloading shapely-2.0.0-cp310-cp310-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 206.3 kB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp310-cp310-win_amd64.whl (12.0 MB)
#      --------------------------------------- 12.0/12.0 MB 53.5 kB/s eta 0:00:00
# Collecting python-bidi
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Collecting opencv-python-headless<=4.5.4.60
#   Downloading opencv_python_headless-4.5.4.60-cp310-cp310-win_amd64.whl (35.0 MB)
#      -------------------------------------- 35.0/35.0 MB 198.1 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from torchvision>=0.5->easyocr) (4.4.0)
# Requirement already satisfied: requests in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: six in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp310-cp310-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 191.9 kB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (21.3)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.23.0-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 272.7 kB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 67.4 kB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      ------------------------------------ 210.3/210.3 kB 148.9 kB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\90505\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.1.1)
# Installing collected packages: pyclipper, ninja, tifffile, Shapely, PyYAML, PyWavelets, python-bidi, opencv-python-headless, networkx, imageio, scikit-image, easyocr
# Successfully installed PyWavelets-1.4.1 PyYAML-6.0 Shapely-2.0.0 easyocr-1.6.2 imageio-2.23.0 networkx-3.0 ninja-1.11.1 opencv-python-headless-4.5.4.60 pyclipper-1.3.0.post4 python-bidi-0.4.2 scikit-image-0.19.3 tifffile-2022.10.10

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
IMAGE_PATH="img/TR_Nat_ID_Card_Front.png"

# %%
reader=easyocr.Reader(['tr'], gpu=False)
result=reader.readtext(IMAGE_PATH)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[53, 17], [295, 17], [295, 31], [53, 31]],
#   'TÜRKIYE CUMHURIYETI KIMLIK KARTI',
#   0.509502782560505),
#  ([[87, 31], [259, 31], [259, 43], [87, 43]],
#   'RFUBIIC OF IURKEY IDFNIIY CARD',
#   0.3920411682573941),
#  ([[11, 69], [85, 69], [85, 83], [11, 83]], '12345678902', 0.9277029192040757),
#  ([[121, 69], [157, 69], [157, 83], [121, 83]], 'ACAR', 0.9195621013641357),
#  ([[119, 101], [165, 101], [165, 113], [119, 113]],
#   'HAKAN',
#   0.8996854006667915),
#  ([[121, 131], [181, 131], [181, 145], [121, 145]],
#   '22 05,1975',
#   0.8385093757380637),
#  ([[209, 131], [233, 131], [233, 145], [209, 145]], 'EiM', 0.8613068234688113),
#  ([[277, 135], [337, 135], [337, 151], [277, 151]],
#   'S123456TC',
#   0.42612119998673376),
#  ([[121, 163], [175, 163], [175, 177], [121, 177]],
#   '7505297F',
#   0.994693056895913),
#  ([[209, 163], [255, 163], [255, 177], [209, 177]],
#   'TCTUR',
#   0.9845347185315216),
#  ([[121, 195], [181, 195], [181, 207], [121, 207]],
#   '?0.07.?017',
#   0.38959740958855854)]

# %%
img=cv2.imread(IMAGE_PATH)
for detection in result:
    top_left=tuple([int(val) for val in detection[0][0]])
    bottom_right=tuple([int(val) for val in detection[0][2]])
    text=detection[1]
    font=cv2.FONT_HERSHEY_SIMPLEX
    img=cv2.rectangle(img, top_left, bottom_right, (0,255,0), 2)
    img=cv2.putText(img, text, top_left, font, 0.45, (255,0,0), 1, cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
for detection in result:
    print(detection[1])
# Out:
# ;ÇŞŞLERT BAKANLIGI
# TÜRKİYE CUMHURIYETI
# REPUBLIC OF TURKEY
# Göc İDAREsİ
# İKAMET İZNİ BELGEsİ
# RESIDENCE PERMIT DOCUMENT
# GENEL MÜDÜRLÜĞÜ
# Yabancı Kimlik No
# Foreigner Identity Number
# 99258138252
# Adı
# Name
# ALI SAJAD
# Soyadı / Surname
# GHAZNAVI
# Uyruğu
# Nationality
# Doğum Tarihi / Date of Birth
# AFGANISTAN
# 03.03.2000
# ikamet İli
# Province of Residance
# Seri No / Document No
# KONYA
# YAA 979708
